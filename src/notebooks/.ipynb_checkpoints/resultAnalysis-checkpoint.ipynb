# %%
import sys; sys.path.insert(0, '../..')
import os
path = '../..'
os.chdir(path)
print(os.getcwd())

import fenics as fa
import matplotlib.pyplot as plt
import itertools

plt.style.use('seaborn')

import numpy as np
import pandas as pd
# Out:
# /Users/tianqin/Desktop/rpa/meta-pde

# %% [markdown]
# ## Poisson

# %%
fenics_result = np.load('poisson_fenics_results/cpu_pore_res/errors_by_resolution.npy', allow_pickle=True)
errs, times = fenics_result

# %%
fenics_baselines = pd.DataFrame()
for res, err in errs.items():
    fenics_baselines = fenics_baselines.append(
    {
        'res_s': res[0],
        'res_b': res[1],
        'mse': (err[0]).astype(float), 
        'rel_mse': (err[2]).astype(float), 
        'std_rel_mse': (err[4]).astype(float), 
        'time (s)': times[res]
    }, ignore_index=True)

fenics_baselines_f = fenics_baselines[['res_s',
                                       'res_b',
                                       'mse',
                                       'rel_mse', 
                                       'std_rel_mse', 
                                       'time (s)']].set_index(['res_s', 'res_b', 'time (s)'])
pd.set_option('display.float_format', '{:.3f}'.format)
display(fenics_baselines_f)
# Out:
#                                           mse                 rel_mse  \
# res_s  res_b time (s)
# 1.000  1.000 0.152       0.023460397496819496      0.0978928878903389
# 2.000  1.000 0.220       0.001365034026093781    0.006259595975279808
# 4.000  1.000 0.433     0.00023724908533040434    0.001288260449655354
# 8.000  1.000 1.038      8.655290002934635e-06   4.328458453528583e-05
# 16.000 1.000 3.980       5.67047777622065e-07  2.1198957256274298e-06
# 32.000 1.000 19.954    3.2610667943799854e-08  1.0165749131374469e-07
#
#                                   std_rel_mse
# res_s  res_b time (s)
# 1.000  1.000 0.152        0.09503509104251862
# 2.000  1.000 0.220       0.006043537985533476
# 4.000  1.000 0.433      0.0019920761696994305
# 8.000  1.000 1.038     5.7319950428791344e-05
# 16.000 1.000 3.980     2.2254155283008004e-06
# 32.000 1.000 19.954    1.0623936930187483e-07

# %%
poisson_leap_results = pd.DataFrame(columns=['expt_name', 'mse', 'rel_mse'])
res_dir = 'poisson_leap_results'

results = os.listdir(res_dir)
for r in results:
    if os.path.isdir(os.path.join(res_dir, r)):  
        #print(f"{r} is a directory", end=' ')  
        if os.path.exists(os.path.join(res_dir, r, 'log.txt')):
            #print(f"   {r} has log file") 
            with open(os.path.join(res_dir, r, 'log.txt')) as f: 
                lines = f.readlines()
                mse = []
                rel_mse = []
                for line in lines:
                    if line.startswith('step'):
                        line_arr = line.split(',')
                        step = int(line_arr[0].split(":")[1])
                        #train_time = step * float(line_arr[-1].split(":")[1])
                        mse_l = float(line_arr[3].split(":")[1])
                        mse.append(mse_l)
                        rel_mse_l = float(line_arr[4].split(":")[1])
                        rel_mse.append(rel_mse_l)
                        
                #print("mse: ", mse, " rel_mse: ", rel_mse)
                poisson_leap_results = poisson_leap_results.append({
                    "expt_name": r, 
                    "mse": np.min(mse), 
                    "rel_mse": np.min(rel_mse)
                },
                    ignore_index=True)
poisson_leap_results = poisson_leap_results.sort_values(['rel_mse'])
poisson_leap_results
# Out:
#          expt_name   mse  rel_mse
# 1   default_7_cont 0.000    0.001
# 0     default_plot 0.000    0.001
# 13       default_6 0.001    0.001
# 14   default_final 0.000    0.001
# 5        default_5 0.001    0.002
# 11       default_8 0.001    0.002
# 10       default_9 0.002    0.006
# 9        default_7 0.009    0.011
# 6        default_2 0.008    0.024
# 8   default_3_cont 0.008    0.024
# 2        default_3 0.007    0.027
# 3        default_4 0.010    0.041
# 12       default_1 0.013    0.052
# 7          default 0.039    0.064
# 4       default_10 0.080    0.136

# %%
line_arr
# Out:
# ['step: 11500',
#  ' meta_loss: 0.0033410966861993074',
#  ' val_meta_loss: 0.001561007578857243',
#  ' val_mse: 0.0005576644907705486',
#  ' val_rel_err: 0.001358437817543745',
#  ' val_rel_err_std: 0.0010381602915003896',
#  ' val_true_norms: [0.46967632]',
#  ' per_dim_rel_err: [0.00135844]',
#  ' per_time_step_error: None',
#  ' deployment_time: 0.3973492681980133meta_grad_norm: 178.92018127441406',
#  ' time: 3.208299160003662',
#  ' key: [1213060758 1502734680]',
#  ' subkey: [3352992011 3671767127]\n']

# %%
def generate_nn_results(directory, expts):
    nn_pde_results = dict()
    nn_pde_time_agg = []
    nn_pde_accuracy_agg = []

    for expt in expts:
        nn_pde_result = []
        with open(f'{directory}/{expt}/log.txt') as f:
            lines = f.readlines()
            train_time_cum = 0.0
            step_prev = 0
            maml_loss = None
            for line in lines:
                if line.startswith('step'):
                    line_arr = line.split(',')
                    step = int(line_arr[0].split(":")[1])
                    if step <= 0:
                        continue
                    per_step_train_time = float(line_arr[-1].split(":")[1])
                    if per_step_train_time > 1:
                        per_step_train_time = 0.01599264144897461
                    train_time_cum += (step - step_prev) * per_step_train_time
                    step_prev = step
                    mse = float(line_arr[3].split(":")[1])
                    nn_pde_result.append([train_time_cum, mse])
        nn_pde_result = np.array(nn_pde_result)
        nn_pde_results[expt] = nn_pde_result

    nn_pde_results_avg = (np.mean(list(nn_pde_results.values()), axis=0))
    #print(nn_pde_results_avg)
    
    return nn_pde_results_avg

# %%
#expts = [f'cpu_maml_pretrain_3_seed_{i + 1}' for i in range(5)]
#nn_pde_results_avg = generate_nn_results('poisson_nn_results' ,expts)

# %%
poisson_maml_results = pd.DataFrame(columns=['expt_name', 'mse', 'rel_mse'])
res_dir = 'poisson_maml_results'

results = os.listdir(res_dir)
for r in results:
    if os.path.isdir(os.path.join(res_dir, r)):  
        #print(f"{r} is a directory", end=' ')  
        if os.path.exists(os.path.join(res_dir, r, 'log.txt')):
            #print(f"   {r} has log file") 
            with open(os.path.join(res_dir, r, 'log.txt')) as f: 
                lines = f.readlines()
                mse = []
                rel_mse = []
                for line in lines:
                    if line.startswith('step'):
                        line_arr = line.split(',')
                        step = int(line_arr[0].split(":")[1])
                        if step < 0:
                            continue
                        #train_time = step * float(line_arr[-1].split(":")[1])
                        mse_l = float(line_arr[3].split(":")[1])
                        mse.append(mse_l)
                        rel_mse_l = float(line_arr[4].split(":")[1])
                        rel_mse.append(rel_mse_l)
                        
                try:
                    poisson_maml_results = poisson_maml_results.append({
                        "expt_name": r, 
                        "mse": np.min(mse), 
                        "rel_mse": np.min(rel_mse)
                    },
                        ignore_index=True)
                except:
                    pass
poisson_maml_results = poisson_maml_results.sort_values(['rel_mse'])
poisson_maml_results
# Out:
#           expt_name   mse  rel_mse
# 9  default_4_cont_2 0.000    0.000
# 8     default_final 0.000    0.000
# 6      default_cont 0.000    0.001
# 5    default_2_cont 0.000    0.001
# 3         default_2 0.000    0.001
# 7    default_4_cont 0.000    0.001
# 0      default_plot 0.000    0.001
# 2         default_4 0.000    0.001
# 1         default_3 0.054    0.076
# 4           default 0.433    0.962

# %%
fig = plt.figure(figsize=(12, 8))
fsize = 15
msize = 20
marker = itertools.cycle(('D', 'X', 'h', 's', '<', '>', 'o', '*')) 
plt.subplot(1, 1, 1)
for res_s in fenics_baselines.res_s.unique():
    fenics_baseline_subset = fenics_baselines[fenics_baselines.res_s == res_s]
    plt.plot(fenics_baseline_subset['time (s)'], fenics_baseline_subset['rel_mse'], marker=next(marker),
             ls='--', markersize=15, label=f'Fenics Spatial Res = {res_s}')
def generate_nn_results(directory, expts):
    nn_pde_results = dict()
    nn_pde_time_agg = []
    nn_pde_accuracy_agg = []

    for expt in expts:
        nn_pde_result = []
        with open(f'{directory}/{expt}/log.txt') as f:
            lines = f.readlines()
            train_time_cum = 0.0
            step_prev = 0
            maml_loss = None
            for line in lines:
                if line.startswith('step'):
                    line_arr = line.split(',')
                    step = int(line_arr[0].split(":")[1])
                    if step <= 0:
                        continue
                    per_step_train_time = float(line_arr[-1].split(":")[1])
                    if per_step_train_time > 1:
                        per_step_train_time = 0.01599264144897461
                    train_time_cum += (step - step_prev) * per_step_train_time
                    step_prev = step
                    mse = float(line_arr[3].split(":")[1])
                    nn_pde_result.append([train_time_cum, mse])
        nn_pde_result = np.array(nn_pde_result)
        nn_pde_results[expt] = nn_pde_result

    nn_pde_results_avg = (np.mean(list(nn_pde_results.values()), axis=0))
    #print(nn_pde_results_avg)
    
    return nn_pde_results_avg

expts = [f'cpu_pretrain_1_seed_{i + 1}' for i in range(8)]
nn_pde_results_avg = generate_nn_results('poisson_nn_results', expts)
plt.plot(nn_pde_results_avg[:, 0], nn_pde_results_avg[:, 1], ls='-', lw=3, 
         label='meta-PDE LEAP(CPU)', color='violet')
plt.plot(nn_pde_results_avg[0:60:5, 0], nn_pde_results_avg[0:60:5, 1], ls='', marker='X', lw=2, 
         color='violet', markersize=msize*0.8)

expts = [f'cpu_maml_pretrain_3_seed_{i + 1}' for i in range(8)]
nn_pde_results_avg = generate_nn_results('poisson_nn_results', expts)
plt.plot(nn_pde_results_avg[:, 0], nn_pde_results_avg[:, 1], ls='-', lw=3, 
         label='meta-PDE MAML(CPU)', color='lightseagreen')
plt.plot(nn_pde_results_avg[0:5, 0], nn_pde_results_avg[0:5, 1], ls='', marker='X', lw=2, 
         color='lightseagreen', markersize=msize*0.8)


def generate_nn_results(directory, expts):
    nn_pde_results = dict()
    nn_pde_time_agg = []
    nn_pde_accuracy_agg = []

    for expt in expts:
        nn_pde_result = []
        with open(f'{directory}/{expt}/log.txt') as f:
            lines = f.readlines()
            train_time_cum = 0.0
            step_prev = 0
            maml_loss = None
            for line in lines:
                if line.startswith('step'):
                    line_arr = line.split(',')
                    step = int(line_arr[0].split(":")[1])
                    if step <= 0:
                        continue
                    per_step_train_time = float(line_arr[-1].split(":")[1])
                    if per_step_train_time > 1:
                        per_step_train_time = 0.00239038467407226
                    train_time_cum += (step - step_prev) * per_step_train_time
                    step_prev = step
                    mse = float(line_arr[3].split(":")[1])
                    nn_pde_result.append([train_time_cum, mse])
        nn_pde_result = np.array(nn_pde_result)
        nn_pde_results[expt] = nn_pde_result

    nn_pde_results_avg = (np.mean(list(nn_pde_results.values()), axis=0))
    
    return nn_pde_results_avg


expts = [f'gpu_pretrain_1_seed_{i + 1}' for i in range(8)]
nn_pde_results_avg = generate_nn_results('poisson_nn_results', expts)
plt.plot(nn_pde_results_avg[:, 0], nn_pde_results_avg[:, 1], ls='dashed', lw=3, 
         label='meta-PDE LEAP(GPU)', color='violet')
plt.plot(nn_pde_results_avg[0:60:5, 0], nn_pde_results_avg[0:60:5, 1], ls='', marker='X', lw=2, 
         color='violet', markersize=msize*0.8)

expts = [f'gpu_maml_pretrain_3_seed_{i + 1}' for i in range(8)]
nn_pde_results_avg = generate_nn_results('poisson_nn_results', expts)
plt.plot(nn_pde_results_avg[:, 0], nn_pde_results_avg[:, 1], ls='dashed', lw=3, 
         label='meta-PDE MAML(GPU)', color='lightseagreen')
plt.plot(nn_pde_results_avg[0:5, 0], nn_pde_results_avg[0:5, 1], ls='', marker='X', lw=2, 
         color='lightseagreen', markersize=msize*0.8)


plt.yscale('log')
plt.xscale('log')
plt.xlabel('Time (s)', fontsize=fsize)
plt.ylabel('MSE', fontsize=fsize)
plt.xticks(fontsize=fsize)
plt.yticks(fontsize=fsize)


plt.legend(fontsize=fsize)
plt.title('Nonlinear Poisson', fontsize=fsize)
plt.savefig('plots/poisson.pdf')
plt.show()

# %% [markdown]
# ## Burgers

# %%
fenics_result = np.load('td_burgers_fenics_results/jax/errors_by_resolution.npy', allow_pickle=True)
times, errs = fenics_result

# %%
fenics_baselines = pd.DataFrame()
for res, err in errs.items():
    fenics_baselines = fenics_baselines.append(
    {
        'res_s': res[0],
        'res_t': res[1],
        'mse': (err[0]).astype(float), 
        'rel_mse': (err[2]).astype(float), 
        'std_rel_mse': (err[4]).astype(float), 
        'time (s)': times[res]
    }, ignore_index=True)

fenics_baselines_f = fenics_baselines[[
    'res_s',
    'res_t',
    'mse',
    'rel_mse', 
    'std_rel_mse', 
    'time (s)'
]].set_index(['res_s', 'res_t', 'time (s)'])
pd.set_option('display.float_format', '{:.3f}'.format)
display(fenics_baselines)
# Out:
#                        mse                rel_mse   res_s   res_t  \
# 0     0.029156018048524857    0.04671693593263626  16.000  17.000
# 1     0.019114702939987183    0.03202157840132713  16.000  33.000
# 2     0.012434765696525574    0.02195536531507969  16.000  65.000
# 3     0.011154256761074066   0.020835431292653084  16.000 129.000
# 4      0.02338232472538948    0.03631621599197388  32.000  17.000
# 5     0.010632158257067204   0.016870221123099327  32.000  33.000
# 6     0.003980032633990049   0.006691605783998966  32.000  65.000
# 7     0.001592238200828433   0.002866698894649744  32.000 129.000
# 8     0.022772785276174545     0.0352194644510746  64.000  17.000
# 9      0.00948723778128624   0.014920092187821865  64.000  33.000
# 10    0.002742388052865863   0.004490790423005819  64.000  65.000
# 11    0.000484293996123597  0.0008190913358703256  64.000 129.000
# 12    0.022757047787308693   0.035157445818185806 128.000  17.000
# 13     0.00941110122948885   0.014778644777834415 128.000  33.000
# 14   0.0026174213271588087   0.004274782259017229 128.000  65.000
# 15   0.0003930098901037127  0.0006484353798441589 128.000 129.000
# 16    0.022747181355953217   0.035131726413965225 256.000  17.000
# 17    0.009401459246873856   0.014759431593120098 256.000  33.000
# 18    0.002605107147246599   0.004249862860888243 256.000  65.000
# 19  0.00038011831929907203  0.0006262118695303798 256.000 129.000
#
#                std_rel_mse  time (s)
# 0      0.01901479810476303    10.575
# 1     0.011614728718996048    14.930
# 2     0.009951521642506123    23.487
# 3     0.009410511702299118    41.169
# 4       0.0175473690032959    10.711
# 5    0.0076537104323506355    15.082
# 6     0.003572464920580387    24.020
# 7    0.0012340419925749302    42.003
# 8      0.01759617030620575    10.980
# 9     0.007920866832137108    15.579
# 10   0.0025602683890610933    24.820
# 11  0.00039607047801837325    43.641
# 12    0.017718056216835976    11.245
# 13    0.007969311438500881    16.391
# 14     0.00256740627810359    26.754
# 15   0.0003855706308968365    47.534
# 16    0.017721164971590042    12.344
# 17    0.007971353828907013    18.389
# 18    0.002555244602262974    30.605
# 19  0.00037119793705642223    55.040

# %%
burgers_leap_results = pd.DataFrame(columns=['expt_name', 'mse', 'rel_mse'])
res_dir = 'td_burgers_leap_results'

results = os.listdir(res_dir)
for r in results:
    if os.path.isdir(os.path.join(res_dir, r)):  
        #print(f"{r} is a directory", end=' ')  
        name_criteria = 'default' in r
        if os.path.exists(os.path.join(res_dir, r, 'log.txt')) and name_criteria:
            #print(f"   {r} has log file") 
            with open(os.path.join(res_dir, r, 'log.txt')) as f: 
                lines = f.readlines()
                mse = []
                rel_mse = []
                for line in lines:
                    if line.startswith('step'):
                        line_arr = line.split(',')
                        step = int(line_arr[0].split(":")[1])
                        #train_time = step * float(line_arr[-1].split(":")[1])
                        mse_l = float(line_arr[3].split(":")[1])
                        mse.append(mse_l)
                        rel_mse_l = float(line_arr[4].split(":")[1])
                        rel_mse.append(rel_mse_l)
                        
                #print("mse: ", mse, " rel_mse: ", rel_mse)
                try:
                    burgers_leap_results = burgers_leap_results.append({
                        "expt_name": r, 
                        "mse": np.min(mse), 
                        "rel_mse": np.min(rel_mse)

                    },
                        ignore_index=True)
                except:
                    print(r)
burgers_leap_results = burgers_leap_results.sort_values(['rel_mse'])
burgers_leap_results
# Out:
# default
#              expt_name   mse  rel_mse
# 13    default_5_cont_2 0.000    0.001
# 8   default_final_cont 0.001    0.001
# 16     default_12_cont 0.001    0.001
# 28       default_final 0.001    0.001
# 20      default_9_cont 0.001    0.001
# 19           default_9 0.001    0.002
# 25    default_6_cont_2 0.001    0.002
# 23      default_5_cont 0.002    0.003
# 29    default_4_cont_2 0.004    0.005
# 15      default_3_cont 0.005    0.005
# 17      default_2_cont 0.005    0.006
# 4            default_3 0.005    0.006
# 12     default_10_cont 0.004    0.007
# 10           default_5 0.005    0.009
# 6           default_10 0.006    0.011
# 21          default_12 0.011    0.016
# 26      default_4_cont 0.015    0.017
# 9      default_11_cont 0.019    0.032
# 27    default_8_cont_2 0.036    0.039
# 2     default_7_cont_2 0.031    0.048
# 0       default_7_cont 0.044    0.072
# 30      default_8_cont 0.051    0.078
# 5            default_4 0.070    0.092
# 18           default_7 0.070    0.110
# 7     default_7_cont_3 0.075    0.127
# 22           default_8 0.095    0.147
# 1       default_6_cont 0.104    0.181
# 3           default_11 0.164    0.280
# 24           default_6 0.179    0.318
# 11           default_2 0.455    0.727
# 14      default_5_redo 0.553    0.875

# %%
def generate_nn_results(directory, expts, missing_time):
    nn_pde_results = dict()
    nn_pde_time_agg = []
    nn_pde_accuracy_agg = []

    for expt in expts:
        nn_pde_result = []
        with open(f'{directory}/{expt}/log.txt') as f:
            lines = f.readlines()
            train_time_cum = 0.0
            step_prev = 0
            maml_loss = None
            for line in lines:
                if line.startswith('step'):
                    line_arr = line.split(',')
                    step = int(line_arr[0].split(":")[1])
                    if step <= 0:
                        continue
                    per_step_train_time = float(line_arr[-1].split(":")[1])
                    if per_step_train_time > 1:
                        per_step_train_time = missing_time
                    train_time_cum += (step - step_prev) * per_step_train_time
                    step_prev = step
                    mse = float(line_arr[3].split(":")[1])
                    nn_pde_result.append([train_time_cum, mse])
        nn_pde_result = np.array(nn_pde_result)
        nn_pde_results[expt] = nn_pde_result

    nn_pde_results_avg = (np.mean(list(nn_pde_results.values()), axis=0))[1:]
    
    return nn_pde_results_avg

# %%
burgers_maml_results = pd.DataFrame(columns=['expt_name', 'mse', 'rel_mse'])
res_dir = 'td_burgers_maml_results'

results = os.listdir(res_dir)
for r in results:
    if os.path.isdir(os.path.join(res_dir, r)):  
        #print(f"{r} is a directory", end=' ')  
        name_criteria = 'default' in r
        if os.path.exists(os.path.join(res_dir, r, 'log.txt')) and name_criteria:
            #print(f"   {r} has log file") 
            with open(os.path.join(res_dir, r, 'log.txt')) as f: 
                lines = f.readlines()
                mse = []
                rel_mse = []
                for line in lines:
                    if line.startswith('step'):
                        line_arr = line.split(',')
                        step = int(line_arr[0].split(":")[1])
                        #train_time = step * float(line_arr[-1].split(":")[1])
                        mse_l = float(line_arr[3].split(":")[1])
                        mse.append(mse_l)
                        rel_mse_l = float(line_arr[4].split(":")[1])
                        rel_mse.append(rel_mse_l)
                        
                #print("mse: ", mse, " rel_mse: ", rel_mse)
                try:
                    burgers_maml_results = burgers_maml_results.append({
                        "expt_name": r, 
                        "mse": np.min(mse), 
                        "rel_mse": np.min(rel_mse)

                    },
                        ignore_index=True)
                except:
                    print(r)
burgers_maml_results = burgers_maml_results.sort_values(['rel_mse'])
burgers_maml_results
# Out:
#         expt_name   mse  rel_mse
# 2       default_3 0.001    0.001
# 4       default_5 0.001    0.001
# 7   default_final 0.001    0.001
# 6       default_6 0.003    0.004
# 1  default_6_cont 0.008    0.010
# 0    default_plot 0.011    0.019
# 3       default_4 0.014    0.023
# 5         default 0.139    0.249

# %%
fig = plt.figure(figsize=(12, 8))
marker = itertools.cycle(('D', 'X', 'h', 's', '<', '>', 'o', '*')) 
fsize = 20
msize = 15
res_s = [16, 32, 64, 128, 256]
for i in range(len(times)):
    plt.plot(times[i], errs[i], marker = next(marker), markersize=msize, label=f'FEA Res = {res_s[i]}')

expts = [f'cpu_pretrain_1_seed_{i + 1}' for i in range(8)]
nn_pde_results_avg = generate_nn_results('td_burgers_nn_results', expts, 0.32973766326904297)
plt.plot(nn_pde_results_avg[:30, 0], nn_pde_results_avg[:30, 1], ls='-', lw=3, 
         label='meta-PDE LEAP(CPU)', color='violet')
plt.plot(nn_pde_results_avg[0:30, 0], nn_pde_results_avg[0:30, 1], ls='', marker='X', lw=2, 
         color='violet', markersize=msize*0.8)

expts = [f'cpu_maml_pretrain_1_seed_{i + 1}' for i in range(8)]
nn_pde_results_avg = generate_nn_results('td_burgers_nn_results', expts, 0.07122421264648438)
plt.plot(nn_pde_results_avg[:, 0], nn_pde_results_avg[:, 1], ls='-', lw=3, 
         label='meta-PDE MAML(CPU)', color='lightseagreen')
plt.plot(nn_pde_results_avg[0:5, 0], nn_pde_results_avg[0:5, 1], ls='', marker='X', lw=2, 
         color='lightseagreen', markersize=msize*0.8)

expts = [f'gpu_pretrain_1_seed_{i + 1}' for i in range(8)]
nn_pde_results_avg = generate_nn_results('td_burgers_nn_results', expts, 0.012534856796264648)
plt.plot(nn_pde_results_avg[:30, 0], nn_pde_results_avg[:30, 1], ls='dashed', lw=3, 
         label='meta-PDE LEAP(GPU)', color='violet')
plt.plot(nn_pde_results_avg[0:30, 0], nn_pde_results_avg[0:30, 1], ls='', marker='X', lw=2, 
         color='violet', markersize=msize*0.8)

expts = [f'gpu_maml_pretrain_1_seed_{i + 1}' for i in range(8)]
nn_pde_results_avg = generate_nn_results('td_burgers_nn_results', expts, 0.01003885269165039)
plt.plot(nn_pde_results_avg[:, 0], nn_pde_results_avg[:, 1], ls='dashed', lw=3, 
         label='meta-PDE MAML(GPU)', color='lightseagreen')
plt.plot(nn_pde_results_avg[0:5, 0], nn_pde_results_avg[0:5, 1], ls='', marker='X', lw=2, 
         color='lightseagreen', markersize=msize*0.8)


plt.yscale('log')
plt.xscale('log')
plt.xlabel('Time (s)', fontsize=fsize)
plt.ylabel('MSE', fontsize=fsize)
plt.xticks(fontsize=fsize)
plt.yticks(fontsize=fsize)
plt.legend(fontsize=fsize*0.8)
plt.title('Time-Dependent Burgers', fontsize=fsize)
plt.tight_layout()

plt.savefig('plots/burgers.pdf')

plt.show()

# %% [markdown]
# # Hyper-elasticity

# %%
fenics_result = np.load('hyper_elasticity_fenics_results/cpu_pore_res/errors_by_resolution.npy', allow_pickle=True)
errs, times = fenics_result

# %%
fenics_baselines = pd.DataFrame()
for res, err in errs.items():
    fenics_baselines = fenics_baselines.append(
    {
        'res_s': res[0],
        'res_b': res[1],
        'mse': (err[0]).astype(float), 
        'rel_mse': (err[2]).astype(float), 
        'std_rel_mse': (err[4]).astype(float), 
        'time (s)': times[res]
    }, ignore_index=True)

fenics_baselines_f = fenics_baselines[['res_s',
                                       'res_b',
                                       'mse',
                                       'rel_mse', 
                                       'std_rel_mse', 
                                       'time (s)']].set_index(['res_s', 'res_b', 'time (s)'])
pd.set_option('display.float_format', '{:.3f}'.format)
display(fenics_baselines_f)
# Out:
#                                            mse                 rel_mse  \
# res_s  res_b  time (s)
# 4.000  2.000  0.959       0.000612785981502384     0.14561529457569122
#        4.000  2.066      0.0005272490088827908     0.12465526908636093
#        6.000  3.341      0.0004982571699656546     0.11582642048597336
#        8.000  4.766      0.0004952181479893625     0.11333832889795303
#        10.000 5.852      0.0003944813215639442      0.0854797437787056
#        12.000 7.486      0.0005911699845455587     0.13382165133953094
# 8.000  2.000  2.092      0.0005384346004575491     0.12766560912132263
#        4.000  4.470      0.0005046191508881748     0.11576925963163376
#        6.000  7.332      0.0005789119168184698     0.13060276210308075
#        8.000  11.074     2.357135781494435e-05    0.005527768284082413
#        10.000 15.480     7.616783022967866e-06    0.002008241368457675
#        12.000 20.565    3.3987025744863786e-06   0.0009121983894146979
# 16.000 2.000  4.749      0.0005458577652461827     0.12388116121292114
#        4.000  10.280    1.3888045032217633e-05    0.003426303854212165
#        6.000  19.460    3.3858423194033094e-06   0.0009460064466111362
#        8.000  32.421      1.81708412583248e-06   0.0005322125507518649
#        10.000 44.638    1.6686379922248307e-06   0.0005029726889915764
#        12.000 60.270     1.852295554272132e-06   0.0005516199744306505
# 32.000 2.000  13.112    0.00022664980497211218    0.058623623102903366
#        4.000  30.621     6.083717494220764e-07  0.00017521041445434093
#        6.000  53.789      5.48971627267747e-07  0.00015998272283468395
#        8.000  88.488     4.920140668218664e-07  0.00014405346882995218
#        10.000 138.177    5.371652491703571e-07  0.00015091455134097487
#        12.000 172.550    7.246453037623724e-07  0.00020052828767802566
#
#                                    std_rel_mse
# res_s  res_b  time (s)
# 4.000  2.000  0.959         0.2244177609682083
#        4.000  2.066        0.19307470321655273
#        6.000  3.341         0.1957230418920517
#        8.000  4.766        0.20025809109210968
#        10.000 5.852        0.19656026363372803
#        12.000 7.486        0.24559752643108368
# 8.000  2.000  2.092        0.19645452499389648
#        4.000  4.470        0.20337440073490143
#        6.000  7.332         0.2428625524044037
#        8.000  11.074       0.00861280970275402
#        10.000 15.480      0.003402986563742161
#        12.000 20.565      0.000870866933837533
# 16.000 2.000  4.749         0.2250903695821762
#        4.000  10.280      0.004743602126836777
#        6.000  19.460       0.00052200339268893
#        8.000  32.421     0.0004199933900963515
#        10.000 44.638    0.00040882197208702564
#        12.000 60.270     0.0005605801125057042
# 32.000 2.000  13.112       0.14669592678546906
#        4.000  30.621      6.58121207379736e-05
#        6.000  53.789     8.152812370099127e-05
#        8.000  88.488     6.821244460297748e-05
#        10.000 138.177    0.0001435111917089671
#        12.000 172.550   0.00020049323211424053

# %%
hyper_elasticity_results = pd.DataFrame(columns=['expt_name', 'mse', 'rel_mse'])
res_dir = 'hyper_elasticity_leap_results'

results = os.listdir(res_dir)
for r in results:
    if os.path.isdir(os.path.join(res_dir, r)):  
        #print(f"{r} is a directory", end=' ')  
        name_criteria = 'full' in r
        if os.path.exists(os.path.join(res_dir, r, 'log.txt')) and name_criteria:
            #print(f"   {r} has log file") 
            with open(os.path.join(res_dir, r, 'log.txt')) as f: 
                lines = f.readlines()
                mse = []
                rel_mse = []
                for line in lines:
                    if line.startswith('step'):
                        line_arr = line.split(',')
                        step = int(line_arr[0].split(":")[1])
                        #train_time = step * float(line_arr[-1].split(":")[1])
                        mse_l = float(line_arr[3].split(":")[1])
                        mse.append(mse_l)
                        rel_mse_l = float(line_arr[4].split(":")[1])
                        rel_mse.append(rel_mse_l)
                        
                #print("mse: ", mse, " rel_mse: ", rel_mse)
                try:
                    hyper_elasticity_results = hyper_elasticity_results.append({
                        "expt_name": r, 
                        "mse": np.min(mse), 
                        "rel_mse": np.min(rel_mse)

                    },
                        ignore_index=True)
                except:
                    print(r)
hyper_elasticity_results = hyper_elasticity_results.sort_values(['mse'])
hyper_elasticity_results
# Out:
# full_5_cont
#        expt_name   mse  rel_mse
# 5         full_3 0.000    0.005
# 0           full 0.000    0.010
# 2         full_2 0.000    0.046
# 10        full_7 0.000    0.004
# 8         full_6 0.000    0.008
# 3         full_5 0.001    0.013
# 9   full_default 0.002    0.063
# 7         full_8 0.002    0.063
# 6   full_10_cont 0.002    0.068
# 1        full_10 0.002    0.067
# 4         full_4 0.004    0.089
# 11        full_9 0.008    0.156

# %%
def generate_nn_results(directory, expts):
    nn_pde_results = dict()
    nn_pde_time_agg = []
    nn_pde_accuracy_agg = []

    #expts = ['pretrain_1_seed_1', 'pretrain_1_seed_2', 'pretrain_1_seed_4', 'pretrain_1_seed_5']

    for expt in expts:
        nn_pde_result = []
        with open(f'{directory}/{expt}/log.txt') as f:
            lines = f.readlines()
            train_time_cum = 0.0
            step_prev = 0
            for line in lines:
                if line.startswith('step'):
                    line_arr = line.split(',')
                    step = int(line_arr[0].split(":")[1])
                    if step < 0:
                        continue
                    per_step_train_time = float(line_arr[-1].split(":")[1])
                    train_time_cum += (step - step_prev) * per_step_train_time
                    step_prev = step
                    mse = float(line_arr[3].split(":")[1])
                    nn_pde_result.append([train_time_cum, mse])
        nn_pde_result = np.array(nn_pde_result)
        nn_pde_results[expt] = nn_pde_result

    nn_pde_results_avg = (np.mean(list(nn_pde_results.values())[1:], axis=0))
    
    return nn_pde_results_avg[1:]

# %%
hyper_elasticity_maml_results = pd.DataFrame(columns=['expt_name', 'mse', 'rel_mse'])
res_dir = 'hyper_elasticity_maml_results'

results = os.listdir(res_dir)
for r in results:
    if os.path.isdir(os.path.join(res_dir, r)):  
        #print(f"{r} is a directory", end=' ')  
        name_criteria = 'default' in r
        if os.path.exists(os.path.join(res_dir, r, 'log.txt')) and name_criteria:
            #print(f"   {r} has log file") 
            with open(os.path.join(res_dir, r, 'log.txt')) as f: 
                lines = f.readlines()
                mse = []
                rel_mse = []
                for line in lines:
                    if line.startswith('step'):
                        line_arr = line.split(',')
                        step = int(line_arr[0].split(":")[1])
                        #train_time = step * float(line_arr[-1].split(":")[1])
                        mse_l = float(line_arr[3].split(":")[1])
                        mse.append(mse_l)
                        rel_mse_l = float(line_arr[4].split(":")[1])
                        rel_mse.append(rel_mse_l)
                        
                #print("mse: ", mse, " rel_mse: ", rel_mse)
                try:
                    hyper_elasticity_maml_results = hyper_elasticity_maml_results.append({
                        "expt_name": r, 
                        "mse": np.min(mse), 
                        "rel_mse": np.min(rel_mse)

                    },
                        ignore_index=True)
                except:
                    print(r)
hyper_elasticity_maml_results = hyper_elasticity_maml_results.sort_values(['mse'])
hyper_elasticity_maml_results
# Out:
#             expt_name   mse  rel_mse
# 4      default_2_cont 0.000    0.002
# 1  default_final_cont 0.000    0.003
# 5        default_cont 0.000    0.004
# 2           default_2 0.000    0.013
# 6       default_final 0.000    0.014
# 3             default 0.001    0.045
# 0       default_small 0.004    0.514

# %%
fig = plt.figure(figsize=(12, 8))
marker = itertools.cycle(('D', 'X', 'h', 's', '<', '>', 'o', '*')) 
fsize=20
msize = 15 
for res_s in fenics_baselines.res_s.unique():
#for res_s in [16., 32., 64., 128.,256.]:
    fenics_baseline_subset = fenics_baselines[fenics_baselines.res_s == res_s]
    plt.plot(fenics_baseline_subset['time (s)'], fenics_baseline_subset['mse'],
             marker = next(marker), ls = '--', markersize=msize, label=f'Fenics Spatial Res = {res_s}')


expts = [f'cpu_pretrain_1_seed_{i + 1}' for i in range(8)]
nn_pde_results_avg = generate_nn_results('hyper_elasticity_nn_results', expts)
plt.plot(nn_pde_results_avg[:, 0], nn_pde_results_avg[:, 1], ls='-', lw=3, 
         label='meta-PDE LEAP(CPU)', color='violet')
plt.plot(nn_pde_results_avg[0:20:5, 0], nn_pde_results_avg[0:20:5, 1], ls='', marker='X', lw=2, 
         color='violet', markersize=msize*0.8)

expts = [f'cpu_maml_pretrain_2_seed_{i + 1}' for i in range(8)]
nn_pde_results_avg = generate_nn_results('hyper_elasticity_nn_results', expts)
plt.plot(nn_pde_results_avg[:, 0], nn_pde_results_avg[:, 1], ls='-', lw=3, 
         label='meta-PDE MAML(CPU)', color='lightseagreen')
#plt.plot(nn_pde_results_avg[0:5, 0], nn_pde_results_avg[0:5, 1], ls='', marker='X', lw=2, 
#         color='lightseagreen', markersize=msize*0.8)


expts = [f'gpu_pretrain_1_seed_{i + 1}' for i in range(8)]
nn_pde_results_avg = generate_nn_results('hyper_elasticity_nn_results', expts)
plt.plot(nn_pde_results_avg[:, 0], nn_pde_results_avg[:, 1], ls='dashed', lw=3, 
         label='meta-PDE LEAP(GPU)', color='violet')
plt.plot(nn_pde_results_avg[0:20:5, 0], nn_pde_results_avg[0:20:5, 1], ls='', marker='X', lw=2, 
         color='violet', markersize=msize*0.8)

expts = [f'gpu_maml_pretrain_1_seed_{i + 1}' for i in range(8)]
nn_pde_results_avg = generate_nn_results('hyper_elasticity_nn_results', expts)
plt.plot(nn_pde_results_avg[:, 0], nn_pde_results_avg[:, 1], ls='dashed', lw=3, 
         label='meta-PDE MAML(GPU)', color='lightseagreen')
#plt.plot(nn_pde_results_avg[0:5, 0], nn_pde_results_avg[0:5, 1], ls='', marker='X', lw=2, 
#         color='lightseagreen', markersize=msize*0.8)



plt.yscale('log')
plt.xscale('log')
plt.xticks(fontsize=fsize)
plt.yticks(fontsize=fsize)
plt.xlabel('Time (s)', fontsize=fsize)
plt.ylabel('MSE', fontsize=fsize)
plt.legend(fontsize=fsize*0.8)
plt.title('Hyperelasticity', fontsize=fsize)
plt.savefig('plots/hyperelasticity.pdf')
plt.show()
